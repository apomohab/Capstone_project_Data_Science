# %% [markdown]
# this data for site udemy.com , this is most popular website for online courses
# we will get more benifits from this data for example
#
# - what is most popular couses ?
# - what is top rating courses ?
# - what is kind populate students ?
# - what is heigh courses price ?
# - what is low courses price ?
#
# and more information used by data science .
#
# - for download this data you can visit the source from kaggle.com
#
# - https://www.kaggle.com/andrewmvd/udemy-courses
#
# for work at this project we will used the ( CRISP - DM ) Rules in data science .
# (Cross-industry standard process for data mining)
#
# # The CRISP - DM including this steps .
#
# - I. Business Understanding
# - II. Data Understanding
# - III. Data Preparation
# - IV. Modeling
# - V. Evaluation
# - VI. Deployment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import plotly 
import folium
import plotly_express
from sklearn.model_selection import cross_val_score
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
from sklearn.model_selection import train_test_split
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error , mean_absolute_error
from sklearn.linear_model import LinearRegression 
df = pd.read_csv('udemy_courses.csv')
import sys
#sys.setrecursionlimit(10000)


#print head data
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
# Print The all coumnns in dataframe.

for x in df.columns:
    print(x)
# Out:
# course_id
# course_title
# url
# is_paid
# price
# num_subscribers
# num_reviews
# num_lectures
# level
# content_duration
# published_timestamp
# subject

# %%
#print how many columnns and rows in dataframe .

df.shape
# Out:
# (3678, 12)

# %%
# More info for data types and columns.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
# Describe data.

df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df['num_lectures'].mean()
# Out:
# 40.108754758020666

# %% [markdown]
# # EDA

# %%
size = df.size
  
# dataframe.shape
shape = df.shape
  
# dataframe.ndim
df_ndim = df.ndim
  

  
# printing size and shape
print("Size = {}\nShape ={}\nShape[0] x Shape[1] = {}".
format(size, shape, shape[0]*shape[1]))
# Out:
# Size = 44136
# Shape =(3678, 12)
# Shape[0] x Shape[1] = 44136

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr() , annot=True, fmt='.1f')
plt.show()

# %%
#vis data for age
sns.barplot(x= df.price.value_counts()[:10].index , y=df.price.value_counts()[:10].values)
plt.xlabel('Prices')
plt.ylabel("Prices Counter")
plt.title("Price Analysis")
plt.show()

# %%
df['price'].value_counts(sort=True).nlargest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['subject'].value_counts(sort=True).nlargest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['course_title'].value_counts(sort=True).nlargest(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['subject'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='subject'>

# %%
df['level'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='level'>

# %%
show = df[['subject','price']].groupby('subject').mean().sort_values(by='price', ascending=False)
show
# Out:
#                          price
# subject
# Web Development      77.033333
# Business Finance     68.552301
# Graphic Design       57.827529
# Musical Instruments  49.558824

# %%
show.plot.bar()
# Out:
# <AxesSubplot:xlabel='subject'>

# %% [markdown]
# # we will look the data and apply the steps CRISP - DM
#
# - Step 1 - 2 : Business understand & Data understand
#
# in this step we need to get answers for some questions from data like examples
#
# 1- what is the level students take the course Introduction to Web Development ?
#
# 2- how many lectures for all courses ?
#
# 3- what is courses published in year 2017  ?
#
# 4- show all sttudent level used by barchart .

# %% [markdown]
# # the first question : what is level students take the course Introduction to Web Development ?

# %%
def level_students():
    
    """
    for answer this question we need to explore the columns  
    [course_title] and [level].
    
    """
    
    #count all types in the varibles course_title
    print(" The All Count course_title  \n \n" + str(df['course_title'].value_counts()) + "\n\n")
    
    #count all types in the varibles Country
    print(" The All Count level  \n \n " + str(df['level'].value_counts())  + "\n\n")
    
    #selected the data we need to get only based on the question .
    interrmediate_Courses = df.loc[(df['course_title'] == 'Introduction to Web Development') & (df['level'])]
    
    #Display The Answer
    print(" The level for students take course Introduction to Web Development" + str(len(interrmediate_Courses)))
    
    #Display the data frame .
    return interrmediate_Courses.head(3)
    
    
level_students()
# Out:
#  The All Count course_title
#
# Acoustic Blues Guitar Lessons                             3
# Creating an animated greeting card via Google Slides      3
# How to Make a Wordpress Website 2017                      2
# Learn Web Designing & HTML5/CSS3 Essentials in 4-Hours    2
# Essentials of money value: Get a financial Life !         2
#                                                          ..
# Classical Guitar Essentials - The Basics Part 2           1
# Stock Technical Analysis with Python                      1
# The Complete Guide to JavaScript Development              1
# How to create a  video blog with WordPress                1
# 2. Principles of Simple Interest - advanced problems      1
# Name: course_title, Length: 3663, dtype: int64
#
#
#  The All Count level
#
#  All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64
#
#
#  The level for students take course Introduction to Web Development2
#       course_id                     course_title  \
# 2607     178640  Introduction to Web Development
# 2660      99986  Introduction to Web Development
#
#                                                     url  is_paid  price  \
# 2607  https://www.udemy.com/introduction-to-web-deve...     True     50
# 2660  https://www.udemy.com/introduction-to-web-deve...     True     20
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2607             5921           35            42  Beginner Level
# 2660            18143          159            15  Beginner Level
#
#       content_duration   published_timestamp          subject
# 2607               4.5  2014-03-11T19:43:30Z  Web Development
# 2660               2.0  2013-10-04T13:40:59Z  Web Development

# %% [markdown]
# # the second question :  how many lectures for all courses ?

# %%
def courses_big_lectures():
    
    """
    for answer this question we need to explore the columns  
    [course_title] and [num_lectures].
    
    """
    
    #count all types in the varibles course_title
    print(" The All Count course_title  \n \n" + str(df['course_title'].value_counts()) + "\n\n")
    
    #count all types in the varibles Country
    print(" The All num_lectures  \n \n " + str(df['num_lectures'].value_counts())  + "\n\n")
    
    
    
    #print  how many lectures in all courses  .
    
    courses_ttitle = df['course_title']
    
    num_lectures = df['num_lectures']
    
    for l, n in zip(courses_ttitle, num_lectures):
        
        print(f' Course Title : {l}')
        
        
        print(f' Number lectures: {n}')
        
        
    return  Courses_lectures
    
    
#Calledd Function    
courses_big_lectures()
# Out:
#  The All Count course_title
#
# Acoustic Blues Guitar Lessons                             3
# Creating an animated greeting card via Google Slides      3
# How to Make a Wordpress Website 2017                      2
# Learn Web Designing & HTML5/CSS3 Essentials in 4-Hours    2
# Essentials of money value: Get a financial Life !         2
#                                                          ..
# Classical Guitar Essentials - The Basics Part 2           1
# Stock Technical Analysis with Python                      1
# The Complete Guide to JavaScript Development              1
# How to create a  video blog with WordPress                1
# 2. Principles of Simple Interest - advanced problems      1
# Name: course_title, Length: 3663, dtype: int64
#
#
#  The All num_lectures
#
#  12     121
# 15     109
# 13     107
# 14     105
# 11     104
#       ...
# 342      1
# 332      1
# 330      1
# 320      1
# 779      1
# Name: num_lectures, Length: 229, dtype: int64
#
#
#  Course Title : Ultimate Investment Banking Course
#  Number lectures: 51
#  Course Title : Complete GST Course & Certification - Grow Your CA Practice
#  Number lectures: 274
#  Course Title : Financial Modeling for Business Analysts and Consultants
#  Number lectures: 51
#  Course Title : Beginner to Pro - Financial Analysis in Excel 2017
#  Number lectures: 36
#  Course Title : How To Maximize Your Profits Trading Options
#  Number lectures: 26
#  Course Title : Trading Penny Stocks: A Guide for All Levels In 2017
#  Number lectures: 25
#  Course Title : Investing And Trading For Beginners: Mastering Price Charts
#  Number lectures: 26
#  Course Title : Trading Stock Chart Patterns For Immediate, Explosive Gains
#  Number lectures: 23
#  Course Title : Options Trading 3 : Advanced Stock Profit and Success Method
#  Number lectures: 38
#  Course Title : The Only Investment Strategy You Need For Your Retirement
#  Number lectures: 15
#  Course Title : Forex Trading Secrets of the Pros With Amazon's AWS
#  Number lectures: 76
#  Course Title : Trading Options With Money Flow
#  Number lectures: 17
#  Course Title : Financial Management Risk and Return For Securities
#  Number lectures: 19
#  Course Title : Forex Trading Course: Work Smarter Not Harder Proven Results
#  Number lectures: 16
#  Course Title : Python Algo Trading: Sentiment Trading with News
#  Number lectures: 42
#  Course Title : Short Selling: Learn To Sell Stocks Before The Fall
#  Number lectures: 19
#  Course Title : Basic Technical Analysis: Learn the structure of the market
#  Number lectures: 16
#  Course Title : The Complete Chart Pattern Trading Course: A Proven Approach
#  Number lectures: 52
#  Course Title : 7 Deadly Mistakes of Investing that Will Slash Your Profits!
#  Number lectures: 23
#  Course Title : Financial Statements Made Easy
#  Number lectures: 12
#  Course Title : Winning Forex Trading with Live Forex Trading Examples
#  Number lectures: 25
#  Course Title : Forex Traders - Create Your First Trading Robot. No Coding!
#  Number lectures: 39
#  Course Title : Create A Business From Home Trading Stocks Today In 2017
#  Number lectures: 16
#  Course Title : Introduction to Accounting : Mastering Financial Statements
#  Number lectures: 23
#  Course Title : The Complete Ethereum Course: Get .01 Ether In Your Wallet
#  Number lectures: 40
#  Course Title : Beginner to Pro in PowerPoint: Complete PowerPoint Training
#  Number lectures: 50
#  Course Title : Investing 101: The Complete Online Investing Course
#  Number lectures: 42
#  Course Title : Create Your Own Hedge Fund: Trade Stocks Like A Fund Manager
#  Number lectures: 25
#  Course Title : Learn MQL5: Build an 8-Currency Hedging Robot (MetaTrader 5)
#  Number lectures: 81
#  Course Title : Forex Trading: Your Complete Guide to Get Started Like a Pro
#  Number lectures: 37
#  Course Title : Python Algo Stock Trading: Automate Your Trading!
#  Number lectures: 41
#  Course Title : THE Forex Robot: Incredible ROI (Robot Included)
#  Number lectures: 35
#  Course Title : The Complete Bitcoin Course: Get .001 Bitcoin In Your Wallet
#  Number lectures: 80
#  Course Title : Mastering High Probability Iron Condor Options Trading
#  Number lectures: 22
#  Course Title : The Complete Short Course on Ethereum
#  Number lectures: 28
#  Course Title : Options Trading Stocks: Proven Toolbox For Financial Success
#  Number lectures: 68
#  Course Title : Forex Trading A-Z™ - With LIVE Examples of Forex Trading
#  Number lectures: 52
#  Course Title : Introduction to Finance, Accounting, Modeling and Valuation
#  Number lectures: 61
#  Course Title : Beginner to Pro in Excel: Financial Modeling and Valuation
#  Number lectures: 138
#  Course Title : The Complete Investment Banking Course 2017
#  Number lectures: 110
#  Course Title : The Complete Financial Analyst Course 2017
#  Number lectures: 174
#  Course Title : Python for Finance: Investment Fundamentals & Data Analytics
#  Number lectures: 103
#  Course Title : Financial Modeling for Startups & Small Businesses
#  Number lectures: 79
#  Course Title : Options Trading - How to Win with Weekly Options
#  Number lectures: 25
#  Course Title : Black Algo Trading: Build Your Trading Robot
#  Number lectures: 227
#  Course Title : Accounting & Financial Statement Analysis: Complete Training
#  Number lectures: 43
#  Course Title : Cryptocurrency Trading: Complete Guide To Trading Altcoins
#  Number lectures: 35
#  Course Title : Forex Robots: Expect To Earn 175% P.A. Forex Robot Included!
#  Number lectures: 42
#  Course Title : Three Steps Trading - Live Trading - Real Account
#  Number lectures: 46
#  Course Title : Option Trading for Rookies:  Understand Options Completely
#  Number lectures: 62
#  Course Title : How I Learned Stock Trading (and How You Can Too)
#  Number lectures: 53
#  Course Title : Learn to Trade for Profit: Find and Trade Winning Stocks
#  Number lectures: 77
#  Course Title : Trading Inside Bars - Master 1 Easy Pattern To Be Successful
#  Number lectures: 23
#  Course Title : Four Fundamentals of Financial Planning
#  Number lectures: 20
#  Course Title : Options Trading - Calendar Spread Course for Every Trader
#  Number lectures: 17
#  Course Title : Dividend Investing: Build Your Portfolio for a Better Future
#  Number lectures: 47
#  Course Title : Learn Accounting. Understand Business.
#  Number lectures: 33
#  Course Title : How to Consistently Win Trading Stocks in 30 Days or Less
#  Number lectures: 15
#  Course Title : A Beginner's Guide to Quantopian Futures API
#  Number lectures: 11
#  Course Title : How to Buy Cheap Options - Options Trading Pricing Model
#  Number lectures: 19
#  Course Title : Excel Crash Course: Master Excel for Financial Analysis
#  Number lectures: 40
#  Course Title : Comprehensive Guide to Financial Markets, Investing &Trading
#  Number lectures: 79
#  Course Title : Stock Trading Ninja: Complete System For Trading Success
#  Number lectures: 38
#  Course Title : Hedge and Mutual Fund Careers: The Complete Guide
#  Number lectures: 102
#  Course Title : Algorithmic Trading In Forex: Create Your First Forex Robot!
#  Number lectures: 40
#  Course Title : The Power Modeling Bootcamp: Advanced Excel in 10 Days
#  Number lectures: 76
#  Course Title : Options Trading Basics (3-Course Bundle)
#  Number lectures: 45
#  Course Title : How to Win 97% of Your Options Trades
#  Number lectures: 26
#  Course Title : How I Make Consistent Returns Trading Options
#  Number lectures: 26
#  Course Title : Forex Strategies: Kelly Criterion, Larry Williams and more!
#  Number lectures: 32
#  Course Title : Elite Trend Trader: Learn To Trade Stocks, Options & Forex
#  Number lectures: 28
#  Course Title : Options Trading Introduction: Day Trade Stock Options
#  Number lectures: 30
#  Course Title : The Almost Perfect Options Trading Strategy System - Unique
#  Number lectures: 15
#  Course Title : Forex Trading -  Learn to Trade Forex Like the Banks
#  Number lectures: 23
#  Course Title : Learn to Trade for Profit:Trading with Japanese Candlesticks
#  Number lectures: 45
#  Course Title : The Most Powerful Options Spread Trading Front Ratio Spread
#  Number lectures: 18
#  Course Title : What Finance Job is for You? Explanation of 14 Finance Roles
#  Number lectures: 60
#  Course Title : The Blueprint for Successful Stock Trading
#  Number lectures: 15
#  Course Title : Trading for Beginners - Intermediate Level
#  Number lectures: 39
#  Course Title : Start Trading Stocks Using Technical Analysis!
#  Number lectures: 45
#  Course Title : Learn How to Set Up an Incubator Hedge Fund - Step-by-Step
#  Number lectures: 54
#  Course Title : VPS for Forex Trading - Protect Your Forex Robots
#  Number lectures: 24
#  Course Title : Introduction to Accounting: The Language of Business
#  Number lectures: 134
#  Course Title : Basic Excel for Basic Bookkeeping and Accounting
#  Number lectures: 33
#  Course Title : Using 'The Greeks To Understand Options"
#  Number lectures: 5
#  Course Title : Trading Options For Consistent Returns: Calendar Spreads
#  Number lectures: 20
#  Course Title : How to Create Your Personal Budget
#  Number lectures: 10
#  Course Title : The Complete Value Investing Course: A Proven Approach
#  Number lectures: 49
#  Course Title : FOREX Trading with Price Action
#  Number lectures: 19
#  Course Title : Emini ES Futures - Advanced Non Directional Options Trading
#  Number lectures: 14
#  Course Title : Forex Trading - Advanced Fundamental Analysis
#  Number lectures: 49
#  Course Title : How To Invest With Tiny Capital In Stocks ?
#  Number lectures: 6
#  Course Title : Learn How To Successfully Trade Stocks: In 5 Simple Steps
#  Number lectures: 108
#  Course Title : Forex MetaTrader 4: Master MT4 Like A Pro Forex Trader
#  Number lectures: 57
#  Course Title : Intermediate Options trading concepts for Stocks and Options
#  Number lectures: 9
#  Course Title : Options Trading 101: The Basics
#  Number lectures: 11
#  Course Title : Practical Accounts APP Overview
#  Number lectures: 14
#  Course Title : Bitcoin Profits for Beginners
#  Number lectures: 30
#  Course Title : Trend Traders Club: How To Find And Trade Fast Moving Trends
#  Number lectures: 60
#  Course Title : Financial Statements Basics
#  Number lectures: 9
#  Course Title : High performance Stock Trading using key Options techniques
#  Number lectures: 6
#  Course Title : Introduction to Financial Statement Analysis
#  Number lectures: 25
#  Course Title : Basics of Economics (College Level)
#  Number lectures: 20
#  Course Title : Stock Market Investing for Beginners
#  Number lectures: 15
#  Course Title : Accounting for Beginners : Learn Basics in under 1 Hour
#  Number lectures: 20
#  Course Title : Straddle Options Trading - Profit in Any Market Direction
#  Number lectures: 19
#  Course Title : Fundamentals of Forex Trading
#  Number lectures: 23
#  Course Title : Binary Options: Trading Strategies, 90% Accuracy and Signals
#  Number lectures: 24
#  Course Title : Website Investing 101 - Buying & Selling Online Businesses
#  Number lectures: 51
#  Course Title : Practical Accounts & Bookkeeping Automated Overview
#  Number lectures: 30
#  Course Title : Live Account - ETF Trading System - Hacking The Stock Market
#  Number lectures: 16
#  Course Title : Stock Market Leverage: How to Start Trading Options Wisely
#  Number lectures: 13
#  Course Title : Stock Market Foundations
#  Number lectures: 9
#  Course Title : Crash Course on Working Capital Management
#  Number lectures: 8
#  Course Title : Advanced Accounting A Complete Study for CA / CMA / CFA / CS
#  Number lectures: 462
#  Course Title : 61% Profit In 1 Month - Crush Your Forex Trading Paradigm
#  Number lectures: 25
#  Course Title : How to create a routine Trading
#  Number lectures: 5
#  Course Title : Forex Trading Secrets |MT4 Robot (EA) inside, no coding
#  Number lectures: 29
#  Course Title : Forex SOS Course: Trading Tweaks And Working Forex Strategy
#  Number lectures: 59
#  Course Title : Introduction to Financial Modeling
#  Number lectures: 8
#  Course Title : Quantitative Aptitude for Banking & Competitive Examinations
#  Number lectures: 42
#  Course Title : Option Spreads and Credit Spreads Bundle
#  Number lectures: 24
#  Course Title : B Com Accountancy I (Paper ECO 02 IGNOU)
#  Number lectures: 284
#  Course Title : FOREX TRADING - Learn in a quick + profitable way + support
#  Number lectures: 47
#  Course Title : Auditing Basics (Professional Course Level)
#  Number lectures: 35
#  Course Title : Stock market Investing Encyclopedia: How to invest in stocks
#  Number lectures: 39
#  Course Title : Learn the basics of preparing accounting statements
#  Number lectures: 20
#  Course Title : Elliott Wave -Forex Trading With The Elliott Wave Theory
#  Number lectures: 14
#  Course Title : Corporate Finance - A Brief Introduction
#  Number lectures: 17
#  Course Title : Excel functions to analyze and visualize data
#  Number lectures: 16
#  Course Title : Building Financial Statements in Excel
#  Number lectures: 18
#  Course Title : Transfer Pricing A Complete Analysis
#  Number lectures: 14
#  Course Title : Accounting: Get Hired Without Work Experience
#  Number lectures: 20
#  Course Title : Forex Trading for Beginners - Basics
#  Number lectures: 11
#  Course Title : Basic Bookkeeping Hacks
#  Number lectures: 28
#  Course Title : Complete Trading Plan Course for Stocks & Forex (10 Hours)
#  Number lectures: 61
#  Course Title : Forex Trading with Fixed 'Risk through Options Trading"
#  Number lectures: 26
#  Course Title : Intro to Investment Banking, M&A, IPO, Modeling + Free Book
#  Number lectures: 15
#  Course Title : How to Pick The Right Penny Stocks To Invest In 2017
#  Number lectures: 23
#  Course Title : Top 10 Trading Ideas in the Equities Market
#  Number lectures: 12
#  Course Title : Intro to Financial Modeling
#  Number lectures: 55
#  Course Title : Shark Accounting - Building a Business by the Numbers!
#  Number lectures: 17
#  Course Title : Forex Trading MAKE YOUR FIRST TRADE TODAY!
#  Number lectures: 45
#  Course Title : Accounting in 60 Minutes - A Brief Introduction
#  Number lectures: 16
#  Course Title : SAP FICO For Beginners - A Guide to SAP Financial Accounts
#  Number lectures: 59
#  Course Title : Learn how to double your Forex Trading Account in one trade
#  Number lectures: 36
#  Course Title : Accounting Superpowers: Learn Accounts, Understand Business!
#  Number lectures: 34
#  Course Title : Python Algo Trading: FX Trading with Oanda
#  Number lectures: 33
#  Course Title : Save on Your Taxes
#  Number lectures: 23
#  Course Title : Financial Model Basics: Build a model from start to finish
#  Number lectures: 13
#  Course Title : Option Trading for Rookies: The Covered Call Option Strategy
#  Number lectures: 29
#  Course Title : EFT for Stock Options Trading Success & Making Better Trades
#  Number lectures: 31
#  Course Title : Learn to Trade the Stock Market without Blowing Your Profits
#  Number lectures: 34
#  Course Title : Get a Credit Repair Publication On Amazon and Live LIFE..
#  Number lectures: 25
#  Course Title : Fundamentals of Accounting
#  Number lectures: 25
#  Course Title : RSI, Options Trading & Technical Analysis (3 Course Bundle)
#  Number lectures: 46
#  Course Title : Basics of Mutual Funds for CA / CMA / CS / CFA Exams
#  Number lectures: 17
#  Course Title : Accounting 101: How to read an Accounting Balance Sheet
#  Number lectures: 22
#  Course Title : Stock Options Day Trading Mindset for Success
#  Number lectures: 43
#  Course Title : Introduction to bookkeeping and Accounting
#  Number lectures: 20
#  Course Title : Learn to Trade The News
#  Number lectures: 544
#  Course Title : Value Investing, Taught by Six Superinvestors
#  Number lectures: 66
#  Course Title : Trading for everyone - The Independent Investor Course I
#  Number lectures: 36
#  Course Title : Get Acquired: Learn From The Head Of Acquisitions For eBay
#  Number lectures: 29
#  Course Title : Stock Market investment: Practical Accounting
#  Number lectures: 43
#  Course Title : How to remove 'Risk from Penny Stocks - Options Trading"
#  Number lectures: 22
#  Course Title : Accounting Basics in 66 Minutes (absolutely for beginners)
#  Number lectures: 14
#  Course Title : Tax Accounting: Difficult Topic, Made Easy to Understand
#  Number lectures: 29
#  Course Title : Analysis of Company Financial Statements
#  Number lectures: 34
#  Course Title : Forex Trading Like Banks – Step by Step with Live Examples
#  Number lectures: 40
#  Course Title : Fundamentals of Investing!
#  Number lectures: 13
#  Course Title : Bank Financial Management A Comprehensive Study
#  Number lectures: 21
#  Course Title : Learn to Trade Forex and Stocks: From Beginner to Advanced
#  Number lectures: 42
#  Course Title : Master 'Technical Analysis and Chart reading skills Bundle"
#  Number lectures: 13
#  Course Title : Naked Put Options Trade Covered Call & Poor Man Covered Call
#  Number lectures: 19
#  Course Title : The Ultimate Guide to Dividend & Dividend Growth Investing
#  Number lectures: 88
#  Course Title : Charting for Beginners 101: Technical Analysis Demystified
#  Number lectures: 10
#  Course Title : Build a DCF Valuation Model
#  Number lectures: 44
#  Course Title : Introductory Financial Accounting
#  Number lectures: 54
#  Course Title : Introduction to Cryptocurrencies and Blockchain
#  Number lectures: 11
#  Course Title : Trade Pullback Candlestick Strategy - Make Consistent Pips
#  Number lectures: 24
#  Course Title : Accounting Standards Basics (Professional Course Level)
#  Number lectures: 12
#  Course Title : Use the Magic Multiple Moving Average Forex Trading system
#  Number lectures: 10
#  Course Title : QuickBooks 2015 Training for Newbies
#  Number lectures: 76
#  Course Title : TRADING PSYCHOLOGY: Trading Mindset Mastery
#  Number lectures: 23
#  Course Title : Option Trading: How to Adjust Delta-Neutral Strangles!
#  Number lectures: 26
#  Course Title : Profitable binary option trading strategy
#  Number lectures: 24
#  Course Title : Tax Strategy: Financial Planning for Beginners
#  Number lectures: 25
#  Course Title : Accounting 2 Simplified for You
#  Number lectures: 27
#  Course Title : Project Funding Modelling (for Professionals)
#  Number lectures: 8
#  Course Title : Investing: How I Consistently Beat The Stock Market
#  Number lectures: 34
#  Course Title : Bookkeeping Basics:  Understand the Fundamentals
#  Number lectures: 48
#  Course Title : Leasing - A Comprehensive Study (Professional Course Level)
#  Number lectures: 22
#  Course Title : Trading Options For Consistent Returns: Options Basics
#  Number lectures: 20
#  Course Title : TechniTrader Leading Hybrid Indicator Trading
#  Number lectures: 5
#  Course Title : Financial modeling: Build a DCF equity valuation model
#  Number lectures: 31
#  Course Title : CryptoArbitrager: Bitcoin Trading Robot (no mining)
#  Number lectures: 14
#  Course Title : Accounting Is Easy (for Beginners)
#  Number lectures: 90
#  Course Title : Non Directional Weekly Options Trading System - ETF & Emini
#  Number lectures: 21
#  Course Title : The Complete Position Trading Course: Position Trading Stock
#  Number lectures: 5
#  Course Title : Master Iron Condors - Double the credit for half the risk
#  Number lectures: 7
#  Course Title : Basics of investing in Mutual Funds
#  Number lectures: 42
#  Course Title : A Value Investing Approach to the Stock Market
#  Number lectures: 15
#  Course Title : Learn how to INVEST for huge profits or make it big trading!
#  Number lectures: 37
#  Course Title : How to Fund your Million Dollar Idea: Equity, Debt, Unfund
#  Number lectures: 54
#  Course Title : Mastering Candlestick Charting : High Probability Trading
#  Number lectures: 35
#  Course Title : Binary Options Course - Level 2
#  Number lectures: 9
#  Course Title : Stock Technical Analysis with R
#  Number lectures: 49
#  Course Title : Get to know the VIX Index (aka 'The Fear Index)"
#  Number lectures: 9
#  Course Title : Apply finance concepts for smart project management
#  Number lectures: 24
#  Course Title : Introduction to Futures Trading and Live Trade Demonstration
#  Number lectures: 6
#  Course Title : Crowdfunding to Win
#  Number lectures: 15
#  Course Title : Comprehensive Forex Mastery Program
#  Number lectures: 97
#  Course Title : Preparation of Consolidated Financial Statements (Basic)
#  Number lectures: 18
#  Course Title : Succeed in Bonds Even if You Don't Know Where to Start
#  Number lectures: 8
#  Course Title : Learn to Trade for Profit: Ten Most Profitable Trading Rules
#  Number lectures: 45
#  Course Title : Succeed in Lotto Even if You Don't Know Where to Start!
#  Number lectures: 18
#  Course Title : CFA Corporate Finance Level 2
#  Number lectures: 128
#  Course Title : Pin Bars: The Most Powerful Forex Trading Signal
#  Number lectures: 19
#  Course Title : Stock Options Trades Using Interactive Brokers
#  Number lectures: 14
#  Course Title : Introduction to Options - Strategies For Consistent Profits
#  Number lectures: 55
#  Course Title : Risk in Forex Transactions - for CA / CS / CFA exams
#  Number lectures: 9
#  Course Title : Basics of Business Statistics (College Level)
#  Number lectures: 28
#  Course Title : Trading Seasonal Price Patterns in Stocks, Futures, & Forex!
#  Number lectures: 13
#  Course Title : Interpreting Financial Statements
#  Number lectures: 23
#  Course Title : Introduction to Bookkeeping (Accounting)
#  Number lectures: 59
#  Course Title : CREDIT SPREAD SURGERY - Bear Call and Bull Put Mastery
#  Number lectures: 16
#  Course Title : Investment Banking: How to Land a Job on Wall Street
#  Number lectures: 63
#  Course Title : Learn To Invest In Index Funds and ETFs In 7 Easy Steps
#  Number lectures: 18
#  Course Title : Financial modeling: Build a multiples valuation model
#  Number lectures: 20
#  Course Title : Trade Recap I - A Real Look at Futures Options Markets
#  Number lectures: 11
#  Course Title : Advanced Stock Options for Serious Equity Investors!
#  Number lectures: 7
#  Course Title : Trading Binary Options for Fun and Profit
#  Number lectures: 46
#  Course Title : CFA: Fast Track your career in Finance
#  Number lectures: 21
#  Course Title : How to be a Profitable Forex Trader
#  Number lectures: 7
#  Course Title : Excel Dashboard - Interactive Excel Dashboard and Charts
#  Number lectures: 34
#  Course Title : Accounting 101: Learn Business Finance Forecasting in 60mins
#  Number lectures: 12
#  Course Title : The Securities Trade Lifecycle
#  Number lectures: 22
#  Course Title : Double your Forex Account using the MAGIC MA trading robot
#  Number lectures: 24
#  Course Title : Technical Analysis 101: How to Profit During Market Crashes
#  Number lectures: 53
#  Course Title : Advanced Accounting for Investment Banking
#  Number lectures: 38
#  Course Title : Investing In Stocks With 10 Simple Rules
#  Number lectures: 59
#  Course Title : Venture Capital. What is it and Why it Matters to You!
#  Number lectures: 25
#  Course Title : Cash Flow Valuation: Develop Your Financial Literacy
#  Number lectures: 19
#  Course Title : Direction-Independ Trading - Elite Forex Traders  Strategy
#  Number lectures: 28
#  Course Title : How to Become a Financial Analyst from Scratch!
#  Number lectures: 38
#  Course Title : First Steps to Trading the Forexmarkets : Technical Analysis
#  Number lectures: 15
#  Course Title : Financial analysis: Compare performance of companies
#  Number lectures: 20
#  Course Title : Forex for Beginners: Easy Forex Trading for Beginners
#  Number lectures: 9
#  Course Title : Investment Crowdfunding 101 (a.k.a Equity Crowdfunding)
#  Number lectures: 11
#  Course Title : Read financial statements like a pro
#  Number lectures: 38
#  Course Title : 10 Numbers Every Business Owner Should Know
#  Number lectures: 9
#  Course Title : Learn How To Trade Gold In 2017
#  Number lectures: 16
#  Course Title : IAS 18 - Revenue
#  Number lectures: 23
#  Course Title : Forex Trading: The High ROI Forex Trading End of Day Course
#  Number lectures: 19
#  Course Title : Fundraise the Simplified Way: A Crowdfunding Blueprint
#  Number lectures: 19
#  Course Title : Fundamentals of Accounting for Business Owners
#  Number lectures: 47
#  Course Title : Practical Financial Statement Analysis
#  Number lectures: 45
#  Course Title : Forex Management - Detailed Study for CA / CS / CFA Exams
#  Number lectures: 38
#  Course Title : Financial Statement Review 101:  How to Find Errors
#  Number lectures: 15
#  Course Title : Professional Risk Manager (PRM) Certification: Level 1
#  Number lectures: 51
#  Course Title : International Tax  - Tax Beyond boundaries
#  Number lectures: 235
#  Course Title : The Complete Financial Statement Analysis Course
#  Number lectures: 37
#  Course Title : Advanced Excel functions
#  Number lectures: 15
#  Course Title : Penny Stocks Value & Chart Pattern Trading (2 Course Bundle)
#  Number lectures: 31
#  Course Title : Candlestick Analysis For Professional Traders
#  Number lectures: 48
#  Course Title : Build A Career In Forex Trading- Learn Fundamental Analysis
#  Number lectures: 52
#  Course Title : Financial Modeling: Build a Complete DCF Valuation Model
#  Number lectures: 44
#  Course Title : Hands-on Financial Modeling (With 6 Excel Templates)
#  Number lectures: 14
#  Course Title : CAIIB Advanced Bank Management (Part I)
#  Number lectures: 211
#  Course Title : Stock Market investment:Non financial fundamental analysis
#  Number lectures: 29
#  Course Title : Learn How to Play CashFlow Game
#  Number lectures: 26
#  Course Title : Basics of Business Finance
#  Number lectures: 24
#  Course Title : Accounting Made Easy 2
#  Number lectures: 40
#  Course Title : Bitcoin: el futuro del dinero, hoy
#  Number lectures: 19
#  Course Title : Aprende a invertir practicando
#  Number lectures: 42
#  Course Title : Trading con retrocesos de Fibonacci
#  Number lectures: 15
#  Course Title : Mit Finanzwissen zu besserem Unternehmertum
#  Number lectures: 23
#  Course Title : Como hacer empresa en 10 sesiones prácticas
#  Number lectures: 10
#  Course Title : المحاسبة للإداريين و غير المحاسبين
#  Number lectures: 17
#  Course Title : 株式投資で本当のファンダメンタル分析ができるようになる
#  Number lectures: 30
#  Course Title : Curso de Trading práctico basado en casos reales
#  Number lectures: 55
#  Course Title : Curso Avanzado de Trading
#  Number lectures: 100
#  Course Title : สอนเทรดไบนารี่ อ๊อฟชั่นอย่างง่าย
#  Number lectures: 25
#  Course Title : MQL4 Tutorial Golden Goose
#  Number lectures: 12
#  Course Title : Análise de Concessão de Crédito
#  Number lectures: 20
#  Course Title : Technical Analysis Using Elliott Wave Theory
#  Number lectures: 16
#  Course Title : The Basics Of Volume Analysis
#  Number lectures: 13
#  Course Title : Crash Course on Cost of Capital and Capital Structuring
#  Number lectures: 19
#  Course Title : Business Accounting Made Easy
#  Number lectures: 26
#  Course Title : Build a DCF Model from Scratch
#  Number lectures: 5
#  Course Title : Multiply your returns using 'Value Investing",https://www.udemy.com/multiply-your-returns-using-value-investing/,true,20,1942,19,63,All Levels,4.5 hours,2015-07-23T00:08:33Z
# 874284,Weekly Forex Analysis by Baraq FX"
#  Number lectures: 14
#  Course Title : Technical Analysis - A practical approach for trade entry
#  Number lectures: 15
#  Course Title : Mastering Technical Analysis : Maximizing Trading Profits
#  Number lectures: 62
#  Course Title : The Complete Guide to Professional Trading with Elliott Wave
#  Number lectures: 43
#  Course Title : A Complete Guide to Becoming a Trader on the Forex Market
#  Number lectures: 15
#  Course Title : Stock Market for Beginners - Complete Starter Toolkit
#  Number lectures: 82
#  Course Title : Beginners Binary Options Course
#  Number lectures: 14
#  Course Title : Technical Analysis 101: Secrets of Trading Revealed
#  Number lectures: 81
#  Course Title : Forex: What's a Trend and When it is Strong and Reliable
#  Number lectures: 30
#  Course Title : Volatility Trading Analysis with R
#  Number lectures: 45
#  Course Title : How To Profit From Stock Market Volatility
#  Number lectures: 11
#  Course Title : Awaken the Accountant in You | Master the Accounting Basics
#  Number lectures: 16
#  Course Title : WE WILL PAY YOU TO TRADE WITH US
#  Number lectures: 11
#  Course Title : Situational Trading: Proven Option Strategy for any Scenario
#  Number lectures: 16
#  Course Title : Portfolio Management for CA / CS / CFA exams
#  Number lectures: 8
#  Course Title : Algorithmic Trading in MATLAB: WFAToolbox App GUI (Finance)
#  Number lectures: 21
#  Course Title : Finding an Unlimited Amount of Investors
#  Number lectures: 6
#  Course Title : Bookkeeping Made Easy
#  Number lectures: 18
#  Course Title : BITCOIN VISUALLY. Part I.
#  Number lectures: 31
#  Course Title : Learn and Master the Basics of Finance
#  Number lectures: 39
#  Course Title : FOREX : LearnTo Trade the Improved ( Advanced ) Patterns
#  Number lectures: 27
#  Course Title : Mastering the Market : (Technical Analysis + Candlestick)
#  Number lectures: 97
#  Course Title : Mastering Countertrend Trading : High Profit Trading Pattern
#  Number lectures: 11
#  Course Title : Exam 1 Review - Managerial Accounting (U of H)
#  Number lectures: 22
#  Course Title : * An Integrated Approach to the Fundamentals of Accounting
#  Number lectures: 123
#  Course Title : Get to grips with the CFA calculator
#  Number lectures: 14
#  Course Title : Financial Model Fundamentals-Learn the Essential Skills
#  Number lectures: 27
#  Course Title : Forex: Economic News Trading
#  Number lectures: 11
#  Course Title : Analyze Real Estate Investments | Financial Modeling
#  Number lectures: 21
#  Course Title : Forex For Beginners - A Guide To Currency Trading
#  Number lectures: 23
#  Course Title : Raise Your Credit Score to 800 Or More....
#  Number lectures: 40
#  Course Title : Financial Management Budgeting Techniques
#  Number lectures: 10
#  Course Title : Forex Killing Divergence - How to trade with precision
#  Number lectures: 11
#  Course Title : Working Capital Management for CA / CFA / CPA Exams
#  Number lectures: 33
#  Course Title : Risk Analysis - Capital Budgeting for CA / CS / CFA exams
#  Number lectures: 47
#  Course Title : Corporate Finance 101: Financial Statement Analysis & Ratios
#  Number lectures: 43
#  Course Title : Mastering Futures Options for Beginners - Your Top 5 Plays!
#  Number lectures: 33
#  Course Title : Professional Options Trading, Simplified
#  Number lectures: 21
#  Course Title : Advanced Options Concepts - Probability, Greeks, Simulation
#  Number lectures: 10
#  Course Title : Accounting Basics - A Complete Study
#  Number lectures: 332
#  Course Title : Case Studies in Macro Economics
#  Number lectures: 22
#  Course Title : My Forex Strategy that win consistently over and over
#  Number lectures: 9
#  Course Title : Understand Banks & Financial Markets
#  Number lectures: 34
#  Course Title : Stock Technical Analysis with Python
#  Number lectures: 46
#  Course Title : How to Become an Accountant from scratch!
#  Number lectures: 15
#  Course Title : How to invest in Gold
#  Number lectures: 39
#  Course Title : Automate Your Finances
#  Number lectures: 21
#  Course Title : MBA Accounting and Finance for Managers(Paper MS04 of IGNOU)
#  Number lectures: 272
#  Course Title : Accounting Made Easy: A Quick Guide to Financial Accounting
#  Number lectures: 18
#  Course Title : Futures/Commodity Training (Basics)
#  Number lectures: 6
#  Course Title : Cost Accounting Marginal Costing Theory and Practice
#  Number lectures: 31
#  Course Title : The Big Volatility Short: The Best Trade On Wall Street!
#  Number lectures: 16
#  Course Title : Master Finance in Three Hours
#  Number lectures: 29
#  Course Title : Learn Options on Futures for Hedging Options and Stocks
#  Number lectures: 6
#  Course Title : Option selling trading as income source. Beginners friendly
#  Number lectures: 61
#  Course Title : Introduction to Value Growth Investing
#  Number lectures: 10
#  Course Title : Become A Forex Trader - Forex trading like a professional
#  Number lectures: 19
#  Course Title : Hedge Fund Trading System
#  Number lectures: 12
#  Course Title : Bulletproof Personal Finance: Expert Asset Allocation
#  Number lectures: 18
#  Course Title : Financial Accounting: The Complete Introductory Crash Course
#  Number lectures: 69
#  Course Title : Learn About Trading Options from a real wallstreet trader
#  Number lectures: 12
#  Course Title : Forex Rate -Why it fluctuates -for CA / CMA / CS / CFA Exams
#  Number lectures: 7
#  Course Title : How to Build a Massive Stock Portfolio from Zero!
#  Number lectures: 129
#  Course Title : Introductory Forex Trading Course
#  Number lectures: 15
#  Course Title : Budgeting Hacks to Build Wealth!
#  Number lectures: 7
#  Course Title : Accounting and Finance for Bankers - A Comprehensive Study
#  Number lectures: 316
#  Course Title : Forex Prep Academy for Beginners-Real trades!
#  Number lectures: 44
#  Course Title : Accounting for Deferred Taxes (Professional Course Level)
#  Number lectures: 11
#  Course Title : TRADING TRUTHS
#  Number lectures: 27
#  Course Title : The Binary Institute - Introductory Course in Binary Options
#  Number lectures: 6
#  Course Title : Forex Trading vs Option Trading
#  Number lectures: 29
#  Course Title : How to Invest in Stocks + Billionaire Investing Tips
#  Number lectures: 19
#  Course Title : Value Investing For Beginners
#  Number lectures: 25
#  Course Title : TRADING TACTICS
#  Number lectures: 62
#  Course Title : MQL4 Tutorial Bootcamp - Trading Robot Coding in Metatrader4
#  Number lectures: 23
#  Course Title : Ultimate Retirement: Build Your Own Dynamic Retirement Plan
#  Number lectures: 37
#  Course Title : build a solid foundation for trading options
#  Number lectures: 8
#  Course Title : Forex Scam: Avoid the scam today
#  Number lectures: 28
#  Course Title : Cost Accounting Crash Course
#  Number lectures: 17
#  Course Title : Option Trading for Rookies: Basic Option Strategies
#  Number lectures: 61
#  Course Title : Business Analysis:  Working with Use Cases
#  Number lectures: 5
#  Course Title : Learn to Raise the Funds You Need via Crowdfunding
#  Number lectures: 70
#  Course Title : Business finances
#  Number lectures: 20
#  Course Title : Financial Accounting - A Brief Introduction
#  Number lectures: 17
#  Course Title : Trading Economic Indicators - Complete Trading System
#  Number lectures: 25
#  Course Title : Foundation of Options Trading and Investing
#  Number lectures: 14
#  Course Title : Option Trading - How To Earn If You Can't Predict The Market
#  Number lectures: 30
#  Course Title : The Financial Analyst Skills Training (FAST) course 2017
#  Number lectures: 138
#  Course Title : Covered Calls - Powerful Income Strategy for Stock Traders
#  Number lectures: 8
#  Course Title : Accounting 1 Simplified for You
#  Number lectures: 13
#  Course Title : [Value Investing] Where White People Keep Their Money
#  Number lectures: 20
#  Course Title : How to Start Investing: Made Simple and Easy
#  Number lectures: 12
#  Course Title : Basics of Commerce A Complete Study
#  Number lectures: 105
#  Course Title : The Passive Investing Blueprint - Build Wealth Passively
#  Number lectures: 66
#  Course Title : 7 Steps: Your Introduction to Trading
#  Number lectures: 176
#  Course Title : Forex - Elliott Wave Theory with Fibonacci.
#  Number lectures: 32
#  Course Title : The Actuarial Profession: Basic Sciences and Principles
#  Number lectures: 7
#  Course Title : Investing in stocks: Avoid stock market loss
#  Number lectures: 13
#  Course Title : QuickBooks Online: Complete Guide & Certification tips
#  Number lectures: 91
#  Course Title : Build Financial Models & Value Companies The Easy Way
#  Number lectures: 18
#  Course Title : Adventure Capital: How to pay off debt
#  Number lectures: 14
#  Course Title : Chart Patterns Trading Demystified
#  Number lectures: 29
#  Course Title : Financial Planning & Analysis: Building a Company's Budget
#  Number lectures: 27
#  Course Title : Simple things you must know before start FOREX (OFFER)
#  Number lectures: 15
#  Course Title : Practical Finance
#  Number lectures: 11
#  Course Title : Forex Trading: Comprehensive & Concise Forex Trading Course
#  Number lectures: 44
#  Course Title : Leaps Options Trading System - Diagonal Leaps Options Spread
#  Number lectures: 16
#  Course Title : Finance - Ratios Analysis & Interpretations
#  Number lectures: 41
#  Course Title : Forex Trading -  Learn to Trade From Scratch!
#  Number lectures: 37
#  Course Title : Technical Analysis tools for Stocks and Options trading
#  Number lectures: 11
#  Course Title : Quantitative Trading Analysis with R
#  Number lectures: 53
#  Course Title : Penny Stocks King: How 2 really Trade Penny Stocks (6 Hours)
#  Number lectures: 48
#  Course Title : Get Started With Penny Stocks -Step by Step Guide to Trading
#  Number lectures: 18
#  Course Title : CPA 101: How To Master Affiliate Marketing In No Time
#  Number lectures: 21
#  Course Title : Corporate Internal Controls and Fraud Controls
#  Number lectures: 12
#  Course Title : Forex trading tactics, that work!
#  Number lectures: 5
#  Course Title : Professional Risk Manager (PRM) Certification: Level 2
#  Number lectures: 55
#  Course Title : Trading Options Basics
#  Number lectures: 8
#  Course Title : Practical Trading on Financial Futures & Options Markets
#  Number lectures: 25
#  Course Title : Bookkeeping made simple
#  Number lectures: 19
#  Course Title : The Visual Learning Basic Accounting Course
#  Number lectures: 6
#  Course Title : ChalkTalk: Financial Accounting
#  Number lectures: 108
#  Course Title : The 7 fundamentals to Successful Cashflow Management
#  Number lectures: 12
#  Course Title : How to trade options
#  Number lectures: 9
#  Course Title : Coaching Course:Investment Analysis for your clients
#  Number lectures: 6
#  Course Title : Harnessing the Power of Growth Stocks
#  Number lectures: 7
#  Course Title : The Investment Banking Recruitment Series
#  Number lectures: 26
#  Course Title : Business Banking 101
#  Number lectures: 14
#  Course Title : CFA Level I Workshop 2: Financial Reporting & Analysis I
#  Number lectures: 5
#  Course Title : Breakout Patterns Workshop by Pattern Trader
#  Number lectures: 15
#  Course Title : Asset Protection Using Offshore Companies
#  Number lectures: 21
#  Course Title : Get Credit for Your EIN That's Not Linked to Your SSN
#  Number lectures: 15
#  Course Title : Financial Translation
#  Number lectures: 29
#  Course Title : How to Pick Stocks
#  Number lectures: 28
#  Course Title : Binary Beginners Mastery Strategy.
#  Number lectures: 14
#  Course Title : Accounting 101-Master Class for Understanding Business
#  Number lectures: 43
#  Course Title : High-Frequency Trading & Dark Pools
#  Number lectures: 22
#  Course Title : How To Crowdfund
#  Number lectures: 17
#  Course Title : Financial Statement Fundamentals for Small Biz & Investors
#  Number lectures: 61
#  Course Title : Master The Stock Market with practice
#  Number lectures: 42
#  Course Title : Introduction to Trade Theory (Technical Analysis) For Stocks
#  Number lectures: 6
#  Course Title : Forex Trading For Beginners: Technical Trading
#  Number lectures: 16
#  Course Title : IAS 12 - Accounting for Income Taxes (Basics)
#  Number lectures: 17
#  Course Title : Surpassing Your Kickstarter Goals
#  Number lectures: 12
#  Course Title : Simple Linear Regression Analysis ( A Complete Course )
#  Number lectures: 29
#  Course Title : Forex: Learn to Trade Forex and FX Consistently
#  Number lectures: 21
#  Course Title : Trading: High-ROI Trading
#  Number lectures: 47
#  Course Title : Fundraising 101
#  Number lectures: 5
#  Course Title : Professional Bookkeeping & Accounting 2 - Bank Daybook
#  Number lectures: 36
#  Course Title : Filing with Companies House UK
#  Number lectures: 9
#  Course Title : Build, Grow, and Protect Your Assets: A Step-by-Step Guide
#  Number lectures: 26
#  Course Title : The Advantages of ETF Options and Index Options Trading
#  Number lectures: 9
#  Course Title : Learn to Trade Forex - from Beginner to Professional
#  Number lectures: 64
#  Course Title : Investing In Stocks For Big Gains, Fundamental Investing
#  Number lectures: 21
#  Course Title : Introduction to Equity Markets
#  Number lectures: 31
#  Course Title : Beginners Guide To Ichimoku Trading
#  Number lectures: 17
#  Course Title : Financial Management - Ratio Analysis
#  Number lectures: 72
#  Course Title : ALGOTECH Hedge Fund Method for Stock Market Trading
#  Number lectures: 4
#  Course Title : Futures/Commodity Trading
#  Number lectures: 23
#  Course Title : Complete Claritas Investment Certificate
#  Number lectures: 35
#  Course Title : Introduction to the economics of public services regulation
#  Number lectures: 69
#  Course Title : Accounting Standard 3 - An Analysis
#  Number lectures: 11
#  Course Title : Essentials of money value: Get a financial Life !
#  Number lectures: 20
#  Course Title : Introduction to Forex Trading Business For Beginners
#  Number lectures: 27
#  Course Title : Cryptocurrency (BTC & ETH) Investment & Trading Course 2017
#  Number lectures: 7
#  Course Title : Introduction to Project Management for Finance and Acct'g
#  Number lectures: 9
#  Course Title : Best Practices in Corporate Budgeting
#  Number lectures: 9
#  Course Title : Financial Statement Auditing Cycles
#  Number lectures: 9
#  Course Title : Case studies on credit appraisal for bankers
#  Number lectures: 15
#  Course Title : Building a Balanced Scorecard
#  Number lectures: 11
#  Course Title : Options Trading Foundation: Your journey to competency...
#  Number lectures: 5
#  Course Title : Forex how traders beat the markest with little experience
#  Number lectures: 16
#  Course Title : CFA Level 2- Quantitative Methods
#  Number lectures: 35
#  Course Title : Foundations of Investing
#  Number lectures: 18
#  Course Title : Capital Market Road Map
#  Number lectures: 21
#  Course Title : TRADING: 5K CHALLENGE
#  Number lectures: 19
#  Course Title : CurrencyFair - Avoid Bank Charges when converting currencies
#  Number lectures: 11
#  Course Title : Bitcoin - A Comprehensive Guide
#  Number lectures: 35
#  Course Title : Forex Trading
#  Number lectures: 25
#  Course Title : The True ' Secret Sauce  For Stock Market Success"
#  Number lectures: 30
#  Course Title : Bookkeeping to Command Senior Bookkeeping Wages
#  Number lectures: 58
#  Course Title : Take Your Career to the Next Level with MBA Finance
#  Number lectures: 19
#  Course Title : How to Read Financial Statements:  Build Financial Literacy.
#  Number lectures: 20
#  Course Title : Accounting Books of Accounts (College Level)
#  Number lectures: 18
#  Course Title : Forex Trading Profitably
#  Number lectures: 15
#  Course Title : Learn How to Trade Pump and Dumps. 5 Setups Well Explained.
#  Number lectures: 18
#  Course Title : Bitcoin Trading 101
#  Number lectures: 19
#  Course Title : Visualizing Data
#  Number lectures: 63
#  Course Title : IFRS Financial Reporting
#  Number lectures: 15
#  Course Title : Forex Trading System: Correlation EUR/GBP vs GBP/USD
#  Number lectures: 26
#  Course Title : SAP Crystal Reports:Master-Detail,Cross-Tab,Sub-Reports
#  Number lectures: 9
#  Course Title : Learn Financial Accounting Different
#  Number lectures: 58
#  Course Title : CFA Level I Workshop 4: Fixed Income and Equity
#  Number lectures: 6
#  Course Title : IAS37 - Provisions, Contingents Liabilities & Assets
#  Number lectures: 29
#  Course Title : What You Should Know to Become a Trader
#  Number lectures: 14
#  Course Title : Financial Reporting A Comprehensive Study
#  Number lectures: 72
#  Course Title : An Abundance Mindset: How to Craft Yours
#  Number lectures: 40
#  Course Title : Forex Trading Profit 183%p.a : Trend is Our Friend-ALGOTREND
#  Number lectures: 12
#  Course Title : How to Build a Massive Retirement Plan from Scratch!
#  Number lectures: 23
#  Course Title : Financial modeling: Build a forward looking financial model
#  Number lectures: 22
#  Course Title : Trading for Beginners - Entry Level
#  Number lectures: 16
#  Course Title : Bitcoin or How I Learned to Stop Worrying and Love Crypto
#  Number lectures: 24
#  Course Title : Trend Following Stocks: A Complete Trading System
#  Number lectures: 64
#  Course Title : Forex Basics
#  Number lectures: 26
#  Course Title : Accounting Bank Reconciliation Statement (College Level)
#  Number lectures: 16
#  Course Title : Bitcoin - Ethereum: Trading -Watch me manage my own account!
#  Number lectures: 22
#  Course Title : FOREX : Learn Technical Analysis
#  Number lectures: 79
#  Course Title : FastTrack to Stock Trading Strategies
#  Number lectures: 12
#  Course Title : Algorithmic futures trading - Investing with no experience
#  Number lectures: 19
#  Course Title : Succeed in Forex Even if You Don't Know Where to Start!
#  Number lectures: 211
#  Course Title : Hedge Fund Accounting and Valuation
#  Number lectures: 11
#  Course Title : Binary, Forex, Stock and Bitcoin Trading Strategy
#  Number lectures: 14
#  Course Title : 2 Easy Steps To Investment And Avoiding Traps
#  Number lectures: 20
#  Course Title : Ethereum Course for Investors
#  Number lectures: 11
#  Course Title : Using Xero for your bookkeeping needs  do beautiful business
#  Number lectures: 28
#  Course Title : Capital Market Immersion
#  Number lectures: 142
#  Course Title : Forex Trading :RSI Indicator-A Secret Weapon
#  Number lectures: 14
#  Course Title : Trading Mindset, and Three Steps To Profitable Trading
#  Number lectures: 24
#  Course Title : Professional Bookkeeping & Accounting 4:Trial Balance & More
#  Number lectures: 21
#  Course Title : Internal Controls - Design, Implementation and Monitoring
#  Number lectures: 27
#  Course Title : Forex online live trading system (Special Offer)
#  Number lectures: 34
#  Course Title : Winning Options Trading System
#  Number lectures: 24
#  Course Title : Learn The ABC's Of Investing And Understanding True Financial Value
#  Number lectures: 8
#  Course Title : How to invest in Russian equity market
#  Number lectures: 12
#  Course Title : Handle difficult questions the bank manager will ask you
#  Number lectures: 12
#  Course Title : Credit Control Procedures
#  Number lectures: 6
#  Course Title : FMT: Forex Market Trader Certificate
#  Number lectures: 27
#  Course Title : Six Stage Negotiation
#  Number lectures: 21
#  Course Title : Financial Reporting - Fundamentals/Basics
#  Number lectures: 28
#  Course Title : Decide whether to Invest in a Business
#  Number lectures: 43
#  Course Title : UK Tax Returns with HMRC
#  Number lectures: 11
#  Course Title : Financial Market Environment & Investment Strategies
#  Number lectures: 25
#  Course Title : How to Obtain a Business Loan
#  Number lectures: 12
#  Course Title : Evolution and Features of ETFs
#  Number lectures: 10
#  Course Title : Cost Accounting Operating Costing(Professional Course Level)
#  Number lectures: 8
#  Course Title : Trade RSI Breakout Strategy: Great Risk/Reward Ratio (Forex)
#  Number lectures: 19
#  Course Title : Day trading strategy for all level, with 72% success rate
#  Number lectures: 15
#  Course Title : Accounting, Finance and Banking - A Comprehensive Study
#  Number lectures: 395
#  Course Title : Advanced Technical Analysis PART1!
#  Number lectures: 19
#  Course Title : Advanced Financial Management for CA / CS / CFA /CPA Exams
#  Number lectures: 194
#  Course Title : Learn the Foundations of Stocks and Options
#  Number lectures: 63
#  Course Title : Forex Trading Masterclass - Learn To Trade Better
#  Number lectures: 30
#  Course Title : Introduction to Accounting - Analyzing Financial Statements
#  Number lectures: 12
#  Course Title : Credit Risk Analysis
#  Number lectures: 19
#  Course Title : Fund Flow Analysis for CA / CFA / CPA Exams
#  Number lectures: 7
#  Course Title : Python for Trading & Investing
#  Number lectures: 36
#  Course Title : Stocks For Beginners - A Guide To Investing
#  Number lectures: 14
#  Course Title : Intro to Impact Investing
#  Number lectures: 12
#  Course Title : Stock Market - Swing Trading Strategies for Wall Street
#  Number lectures: 5
#  Course Title : Essential Options: Strategies for Mastering the Stock Market
#  Number lectures: 27
#  Course Title : The Day Trader: Learn to Trade The Stock Market and Forex
#  Number lectures: 54
#  Course Title : Introduction To The World Of Equity Finance
#  Number lectures: 32
#  Course Title : Stock Technical Analysis with Excel
#  Number lectures: 41
#  Course Title : Beginners Forex strategy
#  Number lectures: 20
#  Course Title : Mortgage Backed Securities
#  Number lectures: 21
#  Course Title : The Complete Financial Model Builder Course-Build 7 Models
#  Number lectures: 88
#  Course Title : Fundamental Financial Math
#  Number lectures: 15
#  Course Title : Equity Swaps
#  Number lectures: 18
#  Course Title : Proven Methods In Trading Candlestick Patterns
#  Number lectures: 22
#  Course Title : Read financial statements as a stock investor
#  Number lectures: 18
#  Course Title : Investing: How to Fix Hidden Flaws Inside Your Portfolio
#  Number lectures: 14
#  Course Title : Certificate Program in Financial Accounting
#  Number lectures: 20
#  Course Title : Trading Biotech Stocks - Understanding the Healthcare Sector
#  Number lectures: 16
#  Course Title : Indian Contract Act 1872: Must for all Finance Professionals
#  Number lectures: 14
#  Course Title : Fundraising Success: The Art & Science of Major Gifts
#  Number lectures: 25
#  Course Title : Smart Trading Techniques for Safe & Consistent Weekly Result
# ...
#  Number lectures: 12
#  Course Title : JQuery Basics - Learn JQuery From Scratch
#  Number lectures: 18
#  Course Title : Learn MeteorJS By Building 10 Real World Projects
#  Number lectures: 79
#  Course Title : JavaScript Basics for Beginners Introduction to coding
#  Number lectures: 18
#  Course Title : AngularJS Masterclass - Deep Dive & Understand AngularJS
#  Number lectures: 85
#  Course Title : HTML5 for beginners
#  Number lectures: 59
#  Course Title : All in one HTML CSS and JQuery
#  Number lectures: 16
#  Course Title : Responsive Design with NEW Materialize
#  Number lectures: 36
#  Course Title : Create a Responsive Business Website with WordPress
#  Number lectures: 38
#  Course Title : PHP webservices
#  Number lectures: 8
#  Course Title : JavaScript Promises: Applications in ES6 and AngularJS
#  Number lectures: 20
#  Course Title : Learn to build 20 websites and build 14 iOS9 apps with swift
#  Number lectures: 458
#  Course Title : Professional CSS Flexbox
#  Number lectures: 21
#  Course Title : XML :basics for beginners
#  Number lectures: 11
#  Course Title : How to create Paypal and Credit card Payment Buttons
#  Number lectures: 8
#  Course Title : Customizr - Learn WordPress with the ultimate creative theme
#  Number lectures: 69
#  Course Title : How To Create a Local Wordpress Environment
#  Number lectures: 12
#  Course Title : Fun and creative web engineering with Python and Web2py
#  Number lectures: 25
#  Course Title : WordPress for Beginners - Build Your First Website in 2017
#  Number lectures: 88
#  Course Title : Learn to Make an Animated Image Gallery using HTML5
#  Number lectures: 7
#  Course Title : Projects in Foundation Framework - Learn By Building 10 Apps
#  Number lectures: 54
#  Course Title : Drupal for Beginners
#  Number lectures: 83
#  Course Title : Laravel : CRUD Application Using AJAX In Laravel 5.3
#  Number lectures: 8
#  Course Title : Foundations of Front-End Web Development
#  Number lectures: 129
#  Course Title : Angular 2 - Superheroic Framework
#  Number lectures: 30
#  Course Title : Social Network Web Development
#  Number lectures: 57
#  Course Title : For Free - Deploy Quickly Spring Boot on Heroku With MySQL
#  Number lectures: 10
#  Course Title : Building Web Applications with Spring MVC
#  Number lectures: 28
#  Course Title : HTML5, CSS3 & Bootstrap - How to Create a Responsive Website
#  Number lectures: 32
#  Course Title : HTML & CSS - Learn to build sleek websites
#  Number lectures: 44
#  Course Title : Master Angular 2 - The No Nonsense Course
#  Number lectures: 36
#  Course Title : Master ASP . NET 4 from scratch
#  Number lectures: 116
#  Course Title : CoffeeScript: The Good Parts—Write Better javaScript
#  Number lectures: 15
#  Course Title : Mastering Magento
#  Number lectures: 40
#  Course Title : Ultimate JavaScript Strings
#  Number lectures: 20
#  Course Title : Your Own Site in 45 Min: The Complete Wordpress Course
#  Number lectures: 36
#  Course Title : Redirect Your Visitors By Country Easily -Wordpress Tutorial
#  Number lectures: 24
#  Course Title : Learn Knockout JS Framework from GroundUp
#  Number lectures: 31
#  Course Title : Build Responsive Websites  in an Hour using Portalfin
#  Number lectures: 17
#  Course Title : Master Riot: Learn Riot.js from Scratch
#  Number lectures: 34
#  Course Title : Learn W3.CSS
#  Number lectures: 10
#  Course Title : Learning Axure RP
#  Number lectures: 65
#  Course Title : Complete guide to install Wordpress, PHP on Cloud,AWS or VPS
#  Number lectures: 28
#  Course Title : Kids Coding -Introduction to HTML, CSS and JavaScript
#  Number lectures: 215
#  Course Title : Introduction to Voice Design with Amazon's Alexa
#  Number lectures: 6
#  Course Title : How to Create a Social Network For a Niche-Related Community
#  Number lectures: 39
#  Course Title : Webpack 1 & 2 - The Complete Guide
#  Number lectures: 79
#  Course Title : Star Rating Project AJAX with JSON response from PHP MySQL
#  Number lectures: 22
#  Course Title : Wordpress for beginners :Build Websites Fast without Coding
#  Number lectures: 68
#  Course Title : ASP.Net MVC Quick Start
#  Number lectures: 65
#  Course Title : Build a Chatbot integrated Website using Bootstrap 4
#  Number lectures: 28
#  Course Title : How To Create A WordPress Website Without Paying A Developer
#  Number lectures: 17
#  Course Title : PSD to Bootstrap 3 for Beginners using HTML & CSS
#  Number lectures: 46
#  Course Title : Build Advanced Responsive Websites with Foundation 6 & SASS
#  Number lectures: 271
#  Course Title : Learn Essential Javascript Fundamentals - Lite
#  Number lectures: 8
#  Course Title : Learn HTML in 2 hours!
#  Number lectures: 13
#  Course Title : Laravel 4 try and enjoy php coding
#  Number lectures: 23
#  Course Title : Wordpress Beginner Tutorial: Build Your First Website
#  Number lectures: 23
#  Course Title : Build Complex Express Sites with Redis and Socket IO
#  Number lectures: 27
#  Course Title : Building a ASP.NET MVC 5 Membership Website
#  Number lectures: 239
#  Course Title : Drupal Views: Introduction to Enhancing Your Drupal Website
#  Number lectures: 40
#  Course Title : Bootstrap Bootcamp - Responsive web development- 8 projects
#  Number lectures: 45
#  Course Title : Self Advertise Using PowerPoint Twitter and Facebook on ios
#  Number lectures: 6
#  Course Title : Learning Bootstrap 3 - Tutorial From Infinite Skills
#  Number lectures: 50
#  Course Title : Practical Web Development: Make Websites Quickly And Easily
#  Number lectures: 20
#  Course Title : Learn animation using CSS3, Javascript and HTML5
#  Number lectures: 18
#  Course Title : Creating Interactive HTML5 Video
#  Number lectures: 23
#  Course Title : Optimizing Wordpress for More Speed and Revenue
#  Number lectures: 7
#  Course Title : JavaScript project Learn to create a memory Game and more
#  Number lectures: 25
#  Course Title : The Complete JavaScript Bootcamp
#  Number lectures: 47
#  Course Title : JavaScript for Absolute Beginners
#  Number lectures: 17
#  Course Title : Complete JavaScript Course for Beginners with Easy Examples
#  Number lectures: 32
#  Course Title : Angular 2 Master Class with Alejandro Rangel
#  Number lectures: 80
#  Course Title : Quick learning jQuery web development
#  Number lectures: 39
#  Course Title : Google Blogger Course
#  Number lectures: 22
#  Course Title : Ajax in JavaScript and JQuery, with PHP - Creating Chat App
#  Number lectures: 15
#  Course Title : PHP Tutorial: Learn PHP Basic Programming for Beginners
#  Number lectures: 23
#  Course Title : Mastering Modern Web Development Using React
#  Number lectures: 29
#  Course Title : Full Stack JavaScript: Learn Backbone.js, Node.js & MongoDB
#  Number lectures: 15
#  Course Title : The Essential Web Developer Course - Build 12 Websites
#  Number lectures: 177
#  Course Title : Build Powerful Websites & Blogs using WordPress - No Coding
#  Number lectures: 26
#  Course Title : Learn to Build Web Apps using UnderscoreJS : Code Like a Pro
#  Number lectures: 27
#  Course Title : Building Web Apps Using Flask and Neo4j
#  Number lectures: 37
#  Course Title : Learn Web Animation the Easy Way: An Intro to SVG and GSAP
#  Number lectures: 15
#  Course Title : Build Your Own Membership Website With Joomla
#  Number lectures: 24
#  Course Title : Learn Spring Security 4 Basics - Hands On
#  Number lectures: 16
#  Course Title : Display and analyze GIS data on the web with Leaflet.js
#  Number lectures: 66
#  Course Title : How to Build a CMS with PHP
#  Number lectures: 10
#  Course Title : Responsive Web Design with HTML5 and CSS3 - Introduction
#  Number lectures: 84
#  Course Title : Master Typescript : Learn Typescript from scratch
#  Number lectures: 60
#  Course Title : XSD :basics for beginners
#  Number lectures: 7
#  Course Title : Angularjs-WebApi2-EFCodeFirst Web App On 3-Tier Architecture
#  Number lectures: 46
#  Course Title : Css Positioning For Absolute Beginners: A Basic Introduction
#  Number lectures: 11
#  Course Title : Creating User Authentication System in CodeIgniter
#  Number lectures: 21
#  Course Title : How to easily Manage your WordPress Website
#  Number lectures: 21
#  Course Title : Wordpress For Beginners: Create a Professional Website
#  Number lectures: 35
#  Course Title : Building a Portfolio in 90 minutes ( HTML, CSS, Js )
#  Number lectures: 24
#  Course Title : Automate Web Development With Gulp JS
#  Number lectures: 29
#  Course Title : Bootstrap 4 Responsive Web Design and Development
#  Number lectures: 73
#  Course Title : Intro To HTML & CSS: Web Development For Beginners
#  Number lectures: 35
#  Course Title : Become Exceptional in HTML and HTML5
#  Number lectures: 34
#  Course Title : Become a Rockstar Web Developer - Learn By Coding
#  Number lectures: 56
#  Course Title : Spring 4 Mastercourse: Covers Annotation & XML Configuration
#  Number lectures: 320
#  Course Title : WordPress Plugin Development for 2017 - Build 14 Plugins
#  Number lectures: 72
#  Course Title : Single Page Application of MVC 5 Using AngularJS
#  Number lectures: 18
#  Course Title : Learn to Code in HTML5, CSS3, and JavaScript
#  Number lectures: 17
#  Course Title : Web Application Development - Learn by Building 3 Web Apps
#  Number lectures: 29
#  Course Title : Rails Ecommerce App with HTML Template from Themeforest
#  Number lectures: 24
#  Course Title : Writing CSS with {LESS} - Tutorial From Infinite Skills
#  Number lectures: 25
#  Course Title : Login and Registration from Scratch with PHP and MySQL
#  Number lectures: 36
#  Course Title : Getting Started with Magento
#  Number lectures: 48
#  Course Title : Ruby on Rails Foundations
#  Number lectures: 73
#  Course Title : Core Concepts in HTML 5
#  Number lectures: 23
#  Course Title : Learn Azure Cloud Step by Step
#  Number lectures: 24
#  Course Title : Learn Facebook Flux Architecture for Web Applications
#  Number lectures: 36
#  Course Title : Create free, fast and secure static website
#  Number lectures: 9
#  Course Title : Object Orientation in PHP
#  Number lectures: 30
#  Course Title : Creating Custom Web Maps
#  Number lectures: 29
#  Course Title : Build A YouTube Downloader With C# And GitHub
#  Number lectures: 32
#  Course Title : Querying Microsoft SQL Server 2012 - (Exam No. 70-461)
#  Number lectures: 115
#  Course Title : HTTP Clients with Laravel: Use and Consume Services and APIs
#  Number lectures: 52
#  Course Title : Modern E-Commerce Store In php & mysqli With Bootstrap
#  Number lectures: 358
#  Course Title : Simple And Easy: Wordpress For Beginners
#  Number lectures: 32
#  Course Title : Create Website from scratch in Urdu & Hindi
#  Number lectures: 9
#  Course Title : Advance Unix : File Processing: AWK | GREP | VIM
#  Number lectures: 12
#  Course Title : Introduction to Node.js Development
#  Number lectures: 16
#  Course Title : Advance JavaScript for Coders: Learn OOP in JavaScript
#  Number lectures: 54
#  Course Title : Web Development With Google Maps
#  Number lectures: 60
#  Course Title : jQuery UI Ultimate:Design Amazing Interfaces Using jQuery UI
#  Number lectures: 69
#  Course Title : Learn Spring Security 4 Intermediate - Hands On
#  Number lectures: 20
#  Course Title : Learning Path: The Road to Elasticsearch
#  Number lectures: 60
#  Course Title : HTML/CSS Bootcamp
#  Number lectures: 87
#  Course Title : JavaScript High Performance
#  Number lectures: 40
#  Course Title : Node:js : Building Rest Apis with Sails.js
#  Number lectures: 44
#  Course Title : Fundamentals of Angular 2 Full Stack Design
#  Number lectures: 49
#  Course Title : Create Newsletter Subscription Form with PHP/AJAX in 40 Min
#  Number lectures: 17
#  Course Title : AppML :basics for beginners
#  Number lectures: 8
#  Course Title : How to manage your own VPS and create websites
#  Number lectures: 30
#  Course Title : Learn BuddyPress: Build A Social Network with WordPress
#  Number lectures: 23
#  Course Title : HTML FOR BEGINNERS
#  Number lectures: 16
#  Course Title : XML XQuery - Crash Course for Beginners
#  Number lectures: 10
#  Course Title : Simplified Cross Browser Web Testing Using VirtualBox
#  Number lectures: 18
#  Course Title : JavaScript and jQuery Basics: Start The Journey
#  Number lectures: 45
#  Course Title : How to Install WordPress From Scratch
#  Number lectures: 13
#  Course Title : CSS :basics for beginners
#  Number lectures: 13
#  Course Title : WordPress Development - Themes, Plugins & Single Page Apps
#  Number lectures: 131
#  Course Title : Learn Effective HTML in No Time!
#  Number lectures: 18
#  Course Title : HTML5 Geolocation in Depth:Build 7 HTML5 Geolocation Apps
#  Number lectures: 86
#  Course Title : Building a Search Engine in PHP & MySQL
#  Number lectures: 12
#  Course Title : create a search engine for your website!
#  Number lectures: 12
#  Course Title : Learn basics of HTML in 30 Minutes
#  Number lectures: 11
#  Course Title : JavaScript from Scratch for Very Beginners
#  Number lectures: 29
#  Course Title : Learn Web Development by Creating a Social Network
#  Number lectures: 80
#  Course Title : CSS Image filters - The modern web images color manipulation
#  Number lectures: 16
#  Course Title : Building Responsive Websites with Bootstrap 3 Framework
#  Number lectures: 27
#  Course Title : Create a Membership Site with Wishlist Member & Wordpress
#  Number lectures: 28
#  Course Title : Convert HTML Websites into PHP: Learn by Doing in 40 Minutes
#  Number lectures: 15
#  Course Title : 17 Complete JavaScript   projects explained step by step
#  Number lectures: 106
#  Course Title : Mastering Unix : AWK Commands
#  Number lectures: 23
#  Course Title : Cakephp:Creating a CRUD application
#  Number lectures: 7
#  Course Title : HTML and CSS: A Guide to Web Design
#  Number lectures: 74
#  Course Title : Drupal 8 Site Building
#  Number lectures: 48
#  Course Title : Learn Bootstrap 4 The Most Popular HTML5 CSS3 & JS Framework
#  Number lectures: 119
#  Course Title : Essentials of Spring 5.0 for Developers
#  Number lectures: 21
#  Course Title : The Extreme Web Development Course - For Beginners
#  Number lectures: 152
#  Course Title : JQuery DOM and Ajax Concept Explained for Beginners
#  Number lectures: 7
#  Course Title : HTML Forms For Beginners: A Basic Introduction
#  Number lectures: 8
#  Course Title : Ultimate JavaScript Objects
#  Number lectures: 65
#  Course Title : The Complete Web Developer Course - Build 20 Websites
#  Number lectures: 304
#  Course Title : Simple Javascript: Learn by Doing, Beginners Welcome!
#  Number lectures: 18
#  Course Title : Learn HTML, CSS, and Ruby on Rails: Build Your First Blog
#  Number lectures: 27
#  Course Title : Learn HTML5 Canvas for beginners
#  Number lectures: 49
#  Course Title : Bootstrap 4 Beginners: Code a Responsive Landing Page
#  Number lectures: 48
#  Course Title : Build Wordpress CMS Clone with Laravel 5
#  Number lectures: 63
#  Course Title : XML DTD - Crash Course for Beginners
#  Number lectures: 10
#  Course Title : Beginner Photoshop to HTML5 and CSS3
#  Number lectures: 22
#  Course Title : XPATH :basics for beginners
#  Number lectures: 8
#  Course Title : The Fastest Way to Create a Website Using Godaddy
#  Number lectures: 12
#  Course Title : A how to guide in HTML
#  Number lectures: 8
#  Course Title : Building Better APIs with GraphQL
#  Number lectures: 16
#  Course Title : Learn Grunt with Examples: Automate Your Front End Workflow
#  Number lectures: 17
#  Course Title : Build A Stock Downloader With Visual Studio 2015 And C#
#  Number lectures: 22
#  Course Title : jQuery UI in Action: Build 5 jQuery UI Projects
#  Number lectures: 140
#  Course Title : Learn jQuery from Scratch - Master of JavaScript library
#  Number lectures: 21
#  Course Title : How To Design A WordPress Website With No Coding At All
#  Number lectures: 42
#  Course Title : Learn and Build using Polymer
#  Number lectures: 48
#  Course Title : CSS Animations: Create Amazing Effects on Your Website
#  Number lectures: 38
#  Course Title : Using MODX CMS to Build Websites: A Beginner's Guide
#  Number lectures: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cbefed85986c> in <module>
#      33
#      34 #Calledd Function
# ---> 35 courses_big_lectures()
#
# <ipython-input-18-cbefed85986c> in courses_big_lectures()
#      29
#      30
# ---> 31     return  Courses_lectures
#      32
#      33
#
# NameError: name 'Courses_lectures' is not defined

# %% [markdown]
# # The question 3 : what is date for published courses ?

# %%
def courses_and_data():  
    
    """
    in this answer need to print what is dates for published courses .
    we will select the columns ['course_title'] andd ['published_timestamp']
    
    """
    
    Courses_name = df['course_title']
    
    Courses_lecture = df['published_timestamp']
    
    #used the functio zip in python.
    for l, n in zip(Courses_name, Courses_lecture):
        
        print(f' Course Title : {l} \n')
        
        print(f'    Published Date: {n} \n')
     


courses_and_data()

# %% [markdown]
# # Question 4 : Provide a pandas series of the all student level values in the dataset , used barchart .

# %%
def sttudent_Levels():
    
    """
    in this question need to provide the student levels 
    used by bar chart .
    """
    
    
    #count the programhobby varible and make bar chart 
    status_vals = df['level'].value_counts()
    
    #devision thee counts at the shape then make bar chart
    (status_vals/df.shape[0]).plot(kind="bar");
    
    #assign the title 
    plt.title("The Studen level ");


#called function
sttudent_Levels()

# %%
# representing the data in heatmap 
sns.heatmap(df.corr(), annot=True, fmt='.2f');

# %% [markdown]
# # The free courses by subject .

# %%
df[df['is_paid']==0].groupby('subject')['num_subscribers'].sum().sort_values(ascending=True).plot(kind='barh')

# %% [markdown]
# # Best paid courses by subject.

# %%
df[df['is_paid']==1].groupby('subject')['num_subscribers'].sum().sort_values(ascending=True).plot(kind='barh')

# %% [markdown]
# # Most popular free courses

# %%
df[df['is_paid']==0].groupby('course_title')['num_subscribers'].sum().sort_values(ascending=True).nlargest(10).plot(kind='barh')

# %% [markdown]
# # Most popular paid courses

# %%
df[df['is_paid']==1].groupby('course_title')['num_subscribers'].sum().sort_values(ascending=True).nlargest(10).plot(kind='barh')

# %% [markdown]
# # step 3  : Prepare Data
#
#  in this step we will working around data and make cleaning data
#   and need to know some info same
#
#  - **what is percent missing values in the varibles**
#  - **what is varibles have more missing values**
#  - **what is frequent values in the varibles**
#  - **what is the best decesion for missing values**
#  - **Assign the predicts varibles and Response varibles**

# %%
def Perecnt_Missing():
    
    '''
    we need to get the percent missing values 
    in all columns for see what is varibles 
    have more missing values.
    
    Missing Values :
    
    the first step in preparing data the "Missing Values" 
    In statistics, missing data, or missing values,
    occur when no data value is stored for the variable
    in an observation Missing data are a common occurrence and 
    can have a significant effect on the conclusions
    that can be drawn from the data.
    '''
    
    #select the missing values and get sum then 
    #multiplication * 100 then division at the len dataframe 
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({'Column_name': df.columns,
                                 'percent_missing': percent_missing})
    
    #Display from 0 to 20 columns
    return missing_value_df[0:20]


#called function
Perecnt_Missing()

# %% [markdown]
# # Prepare data for modeling ..

# %% [markdown]
# - Chose the predicts varibles inside list and check the missing values in this varibles
# - Assign the predict varible
# - Assign the responnse varible

# %%
def Process_Data_For_ML(df):
    
    '''
    Predicted Varible :
    
    Predictor variable is the name given to an independent
    variable used in regression analyses The predictor 
    variable provides information on an associated dependent 
    variable regarding a particular outcome The term predictor
    variable arises from an area of applied mathematic that uses
    probability theory to estimate future occurrences of an event
    based on collected quantitative evidence.
    '''
 
    #in this code we will know how many percent the missing values in predict varibles 
    #create list have the Predicted Varible 
    
    predict_varibles  = df[['num_lectures' , 'num_reviews' , 'level', 'content_duration']]
    
    #get the sum missing values and multiplication * 100 then division at the len dataframe
    percent_missing = predict_varibles.isnull().sum() * 100 / len(df)
    
    
    #Display
    
    print(percent_missing)
    
    
    '''
    Convert The Predict Category Varible To Quantitative. 
    
    In science Machine learning, we use machine learning algorithms
    Those algorithms take the data that we will identify in the prediction
    and response variables and train the model on them so that it can predict
    more accurate values that are suitable for dependence But if the data for 
    those variables is text, we will convert them into digital data, between 0 and 1
    which is because machine learning algorithms  work on Quantitative data 
    so that they can predict more accurate values in the model
    
    '''
    
    

    #used get_dummies method for transfer Category to 0 nad 1.
    
    df_new = pd.get_dummies(predict_varibles, dummy_na=False)
    
    
    '''
     
    get_dummies :
    
    the get_dummies is metthod used for Convert 
    categorical variable into dummy/indicator variables.
    
    Concat :
    
    Pandas concat() method is used to concatenate pandas
    objects such as DataFrames and Series.
    we use (concat) after used the method get_dummies
    for add the new varibles That was converted from  
    Category to Quantitative to DataFrame .
    
    '''

    #add the new data to data framne used method concat.
    
    df = pd.concat([df , df_new], axis=1)
    
    
    
    #drop the main varibles after concat. 
    df.drop('num_lectures',axis='columns', inplace=True)
    df.drop('num_reviews',axis='columns', inplace=True)
    df.drop('level',axis='columns', inplace=True)
    df.drop('content_duration',axis='columns', inplace=True)
    

    #add global functon to predict varible for used out main method
    
    global X

    #Assign the predicted varibles called X
    
    X = df_new

    #add global functon to predict varible for used out main method
    
    global Y
       
    '''
    Response Varible :
    
    Response variables are also known as dependent variables,
    y-variables, and outcome variables. Typically, you want to
    determine whether changes in the predictors are associated 
    with changes in the response.
    
    For example, in a plant growth study, the response variable
    is the amount of growth that occurs during the study. 
    The investigators want to determine how changes in the
    predictors are associated with changes in plant growth. 
    The predictors are the amount of fertilizer applied,
    the soil moisture, and the amount of sunlight.
    
    "Meet Jim"
    '''
    
    #Assign the Response varible called Y
    
    Y = df['price']
    

    
    #return data head 
    return (X.head())
    
    
        
    
    
#called function
Process_Data_For_ML(df)
# Out:
# num_lectures        0.0
# num_reviews         0.0
# level               0.0
# content_duration    0.0
# dtype: float64
#    num_lectures  num_reviews  content_duration  level_All Levels  \
# 0            51           23               1.5                 1
# 1           274          923              39.0                 1
# 2            51           74               2.5                 0
# 3            36           11               3.0                 1
# 4            26           45               2.0                 0
#
#    level_Beginner Level  level_Expert Level  level_Intermediate Level
# 0                     0                   0                         0
# 1                     0                   0                         0
# 2                     0                   0                         1
# 3                     0                   0                         0
# 4                     0                   0                         1

# %% [markdown]
# ### Type of problem.
#
# In this model, we provide a solution to a problem of (LinearRegression) in machine Learning science and all under the category of directed learning, these problems are concerned with predicting prices in the majority of problems that need solutions of this type.
#
# Super vised learning problems have several algorithms One of the most famous (LinearRegression) Which we will apply in building this model

# %%
def data_modeling():
    
    '''
    in this section we will building the model
    for predict the salary based on the 
    Predict data .
    '''

#split data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .30, random_state=42) 

# Instantiate Model
model = LinearRegression(normalize=True) 

#Fit Model
model.fit(X_train, Y_train) 

#Predict and score the model
predict = model.predict(X_test) 

#Display Predict
print(predict[0:100])

#called function
data_modeling()
# Out:
# [ 54.   55.   65.   58.   49.5  68.5  67.5  58.   59.   61.   51.   71.5
#   50.   72.   50.  104.   64.5  69.   73.5  84.   47.   82.5  51.   87.5
#   64.   57.5  73.   52.5  54.   82.   47.   58.5  58.5  47.5  73.   62.
#   46.5  66.   47.5  67.   76.   52.   52.5  55.5  58.5  64.   49.5  72.
#   47.5  57.5  61.  211.   63.   56.5  51.5  49.5  73.5  51.5  73.   48.
#   52.   74.   74.   86.5  50.   65.5  48.5  53.   68.   60.5  54.  102.
#   92.5  69.   60.5  96.   60.   66.   61.5  60.   64.5  53.5  63.5  72.5
#   62.   71.  108.5  61.5  50.   59.   66.   66.5  63.   67.5  90.   58.5
#   51.   56.5  72.5  70.5]

# %% [markdown]
# After building the model and training it on the training data and dividing the data into training and testing data, we tested the model on a set of data to predict the prices of the courses according to the response variable data.

# %% [markdown]
# # Model Accurecy.
#
# In linear regression problems, we have some well-known algorithms in evaluating the performance of the model, which we will apply to our model
#
# Among the most famous evaluation algorithms used with regression problems are
#
# - 1- mean_squared_error
# - 2- mean_absolute_error
# - 3- r2_score

# %%
#Model Accurecy.
def evaluated():
    
    '''
    this is final step in analysis 
    we will evaluated Results model
    used by Accuricy algorithms
    '''
    
    #Accuracy Model used Algorithm (Mean Squared Error)
    print("The mean squared score for the model {} ".format(mean_squared_error(Y_test, predict)))
    
    #Accuracy Model used Algorithm (mean_absolute_error)
    print("The mean_absolute_error for the model {}".format(mean_absolute_error(Y_test, predict)))
    
    #Accuracy Model used Algorithm (R2)
    print("The R2 score for the model {} ".format(r2_score(Y_test, predict)))
    
evaluated()
# Out:
# The mean squared score for the model 3362.33740942029
# The mean_absolute_error for the model 45.19202898550725
# The R2 score for the model 0.11244345082514418

# %%
# used cross validation for split data .
def cross_val():
    
    '''
    Cross-validation is a statistical method used to 
    estimate the skill of machine learning models.
    '''
    
    
    scores = cross_val_score(model , X , Y , cv=5)
    print(scores)

cross_val()
# Out:
# [0.03957751 0.04846695 0.03222555 0.12681011 0.1768304 ]
